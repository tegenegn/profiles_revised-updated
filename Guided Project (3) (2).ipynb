# %% [markdown]
# # Let's find a data set:
#
# ### 60000 online dating profiles
#
# ### [Published](http://ww2.amstat.org/publications/jse/v23n2/kim.pdf) in the [Journal of Statistics Education](http://ww2.amstat.org/publications/jse/), Volume 23, Number 2 (2015) by Albert Y. Kim et al.
#
# ### CFAA: Explicitly allowed by OkCupid co-founder and CEO [Christian Rudder](http://blog.okcupid.com/)
#
# ### Ethically and legally acceptable
#
# ### [Wired article about ethical issues](https://www.wired.com/2016/05/okcupid-study-reveals-perils-big-data-science/))

# %% [markdown]
# ## Go to https://github.com/rudeboybert/JSE_OkCupid/raw/master/profiles_revised.csv.zip
# ## Click on the download button on the right side of the page
# ## upload that file into jupyter notebooks

# %%
# !unzip profiles_revised.csv.zip
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline
df = pd.read_csv('profiles_revised.csv')

# %%
df.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   36         average       mostly other     often  sometimes
# 2   37            thin           anything  socially        NaN
# 3   22            thin         vegetarian  socially        NaN
# 4   30        athletic                NaN  socially      never
#
#                            education            ethnicity  height  income  \
# 0      working on college/university         asian, white    75.0      -1
# 1              working on space camp                white    70.0   80000
# 2     graduated from masters program                  NaN    68.0      -1
# 3      working on college/university                white    71.0   20000
# 4  graduated from college/university  asian, black, other    66.0      -1
#
#                            job                                     offspring  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59946 entries, 0 to 59945
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          59946 non-null  int64
#  1   body_type    54650 non-null  object
#  2   diet         35551 non-null  object
#  3   drinks       56961 non-null  object
#  4   drugs        45866 non-null  object
#  5   education    53318 non-null  object
#  6   ethnicity    54266 non-null  object
#  7   height       59943 non-null  float64
#  8   income       59946 non-null  int64
#  9   job          51748 non-null  object
#  10  offspring    24385 non-null  object
#  11  orientation  59946 non-null  object
#  12  pets         40025 non-null  object
#  13  religion     39720 non-null  object
#  14  sex          59946 non-null  object
#  15  sign         48890 non-null  object
#  16  smokes       54434 non-null  object
#  17  speaks       59896 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# age                0
# body_type       5296
# diet           24395
# drinks          2985
# drugs          14080
# education       6628
# ethnicity       5680
# height             3
# income             0
# job             8198
# offspring      35561
# orientation        0
# pets           19921
# religion       20226
# sex                0
# sign           11056
# smokes          5512
# speaks            50
# status             0
# dtype: int64

# %%
df.fillna( 'unknown', inplace = True)

# %%
df.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   36         average       mostly other     often  sometimes
# 2   37            thin           anything  socially    unknown
# 3   22            thin         vegetarian  socially    unknown
# 4   30        athletic            unknown  socially      never
#
#                            education            ethnicity height  income  \
# 0      working on college/university         asian, white   75.0      -1
# 1              working on space camp                white   70.0   80000
# 2     graduated from masters program              unknown   68.0      -1
# 3      working on college/university                white   71.0   20000
# 4  graduated from college/university  asian, black, other   66.0      -1
#
#                            job                                     offspring  \
# ...

# %%
df.rename(columns = {'sex' : 'gender'}, inplace = True)

# %%
df.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   36         average       mostly other     often  sometimes
# 2   37            thin           anything  socially    unknown
# 3   22            thin         vegetarian  socially    unknown
# 4   30        athletic            unknown  socially      never
#
#                            education            ethnicity height  income  \
# 0      working on college/university         asian, white   75.0      -1
# 1              working on space camp                white   70.0   80000
# 2     graduated from masters program              unknown   68.0      -1
# 3      working on college/university                white   71.0   20000
# 4  graduated from college/university  asian, black, other   66.0      -1
#
#                            job                                     offspring  \
# ...

# %%
df['gender'].value_counts()
# Out:
# m    35829
# f    24117
# Name: gender, dtype: int64

# %%
df['ethnicity'].value_counts()
# Out:
# white                                                                 32831
# asian                                                                  6134
# unknown                                                                5680
# hispanic / latin                                                       2823
# black                                                                  2008
#                                                                       ...
# middle eastern, indian, white                                             1
# asian, middle eastern, black, white, other                                1
# asian, middle eastern, indian, hispanic / latin, white, other             1
# black, native american, indian, pacific islander, hispanic / latin        1
# asian, black, indian                                                      1
# Name: ethnicity, Length: 218, dtype: int64

# %%
df['orientation'].value_counts()
# Out:
# straight    51606
# gay          5573
# bisexual     2767
# Name: orientation, dtype: int64

# %%
df['job'].value_counts()
# Out:
# unknown                              8198
# other                                7589
# student                              4882
# science / tech / engineering         4848
# computer / hardware / software       4709
# artistic / musical / writer          4439
# sales / marketing / biz dev          4391
# medicine / health                    3680
# education / academia                 3513
# executive / management               2373
# banking / financial / real estate    2266
# entertainment / media                2250
# law / legal services                 1381
# hospitality / travel                 1364
# construction / craftsmanship         1021
# clerical / administrative             805
# political / government                708
# rather not say                        436
# transportation                        366
# unemployed                            273
# retired                               250
# military                              204
# Name: job, dtype: int64

# %%
df['income'].value_counts()
# Out:
# -1          48442
#  20000       2952
#  100000      1621
#  80000       1111
#  30000       1048
#  40000       1005
#  50000        975
#  60000        736
#  70000        707
#  150000       631
#  1000000      521
#  250000       149
#  500000        48
# Name: income, dtype: int64

# %%
df['age'].value_counts()
# Out:
# 27     3671
# 26     3643
# 25     3605
# 28     3470
# 29     3324
# 30     3085
# 24     3053
# 31     2784
# 23     2599
# 32     2563
# 33     2223
# 22     2000
# 34     1952
# 35     1740
# 36     1597
# 37     1432
# 21     1350
# 38     1255
# 39     1223
# 40     1062
# 41     1018
# 42      940
# 20      931
# 43      903
# 44      739
# 19      659
# 45      655
# 46      575
# 47      531
# 48      486
# 49      460
# 50      401
# 51      376
# 52      335
# 18      295
# 53      289
# 56      280
# 54      256
# 55      255
# 57      245
# 58      231
# 61      201
# 59      191
# 60      189
# 62      145
# 63      141
# 64      113
# 65      108
# 66      103
# 17       94
# 67       78
# 68       54
# 69       25
# 70       11
# 111       1
# 109       1
# Name: age, dtype: int64

# %%
df['religion'].value_counts()
# Out:
# unknown                                       20226
# agnosticism                                    2724
# other                                          2691
# agnosticism but not too serious about it       2636
# agnosticism and laughing about it              2496
# catholicism but not too serious about it       2318
# atheism                                        2175
# other and laughing about it                    2119
# atheism and laughing about it                  2074
# christianity                                   1957
# christianity but not too serious about it      1952
# other but not too serious about it             1554
# judaism but not too serious about it           1517
# atheism but not too serious about it           1318
# catholicism                                    1064
# christianity and somewhat serious about it      927
# atheism and somewhat serious about it           848
# other and somewhat serious about it             846
# ...

# %%
df['diet'].value_counts()
# Out:
# unknown                24395
# mostly anything        16585
# anything                6183
# strictly anything       5113
# mostly vegetarian       3444
# mostly other            1007
# strictly vegetarian      875
# vegetarian               667
# strictly other           452
# mostly vegan             338
# other                    331
# strictly vegan           228
# vegan                    136
# mostly kosher             86
# mostly halal              48
# strictly halal            18
# strictly kosher           18
# halal                     11
# kosher                    11
# Name: diet, dtype: int64

# %%
df['drinks'].value_counts()
# Out:
# socially       41780
# rarely          5957
# often           5164
# not at all      3267
# unknown         2985
# very often       471
# desperately      322
# Name: drinks, dtype: int64

# %%
df['drugs'].value_counts()
# Out:
# never        37724
# unknown      14080
# sometimes     7732
# often          410
# Name: drugs, dtype: int64

# %%
df['age'].mean()
# Out:
# 32.33540186167551

# %%
df['age'].max()
# Out:
# 111

# %%
df['age'].min()
# Out:
# 17

# %%
df['income'].mean()
# Out:
# 20033.222533613585

# %%
df['income'].max()
# Out:
# 1000000

# %%
df['income'].min()
# Out:
# -1

# %%
df.corr()
# Out:
#              age    income
# age     1.000000 -0.001086
# income -0.001086  1.000000

# %%
df['income'].groupby(df['gender']).mean()
# Out:
# gender
# f    11181.697392
# m    25991.307656
# Name: income, dtype: float64

# %%
df['age'].groupby(df['drugs']).mean()
# Out:
# drugs
# never        33.187732
# often        25.995122
# sometimes    29.871055
# unknown      31.589702
# Name: age, dtype: float64

# %%
df['income'].groupby(df['drinks']).mean()
# Out:
# drinks
# desperately    92452.695652
# not at all     21171.571472
# often          29369.864446
# rarely         18763.705221
# socially       18337.863834
# unknown        13235.256951
# very often     69787.050955
# Name: income, dtype: float64

# %%
pd.crosstab(df['religion'], df['drinks'], normalize = True)
# Out:
# drinks                                      desperately  not at all     often  \
# religion
# agnosticism                                    0.000234    0.001551  0.004954
# agnosticism and laughing about it              0.000400    0.001752  0.005271
# agnosticism and somewhat serious about it      0.000100    0.000484  0.001118
# agnosticism and very serious about it          0.000100    0.000350  0.000617
# agnosticism but not too serious about it       0.000200    0.001802  0.004170
# atheism                                        0.000234    0.001585  0.004888
# atheism and laughing about it                  0.000417    0.001785  0.004638
# atheism and somewhat serious about it          0.000083    0.000817  0.001902
# atheism and very serious about it              0.000100    0.000834  0.001718
# atheism but not too serious about it           0.000133    0.000951  0.003203
# buddhism                                       0.000033    0.000651  0.000384
# ...

# %%
pd.crosstab(df['religion'], df['drugs'])
# Out:
# drugs                                       never  often  sometimes  unknown
# religion
# agnosticism                                  1601      8        367      748
# agnosticism and laughing about it            1283     12        530      671
# agnosticism and somewhat serious about it     329      5        140      168
# agnosticism and very serious about it         152      5         76       81
# agnosticism but not too serious about it     1630     15        386      605
# atheism                                      1125     22        393      635
# atheism and laughing about it                 966     26        518      564
# atheism and somewhat serious about it         445      6        209      188
# atheism and very serious about it             279     19        161      111
# atheism but not too serious about it          704     14        256      344
# buddhism                                      250      0         40      113
# ...

# %%
pd.crosstab(df['gender'], df['drinks'])
# Out:
# drinks  desperately  not at all  often  rarely  socially  unknown  very often
# gender
# f               114        1233   1850    2408     17223     1112         177
# m               208        2034   3314    3549     24557     1873         294

# %%
pd.crosstab(df['pets'], df['religion'])
# Out:
# religion                         agnosticism  \
# pets
# dislikes cats                              3
# dislikes dogs                              2
# dislikes dogs and dislikes cats            6
# dislikes dogs and has cats                 4
# dislikes dogs and likes cats              10
# has cats                                  76
# has dogs                                 200
# has dogs and dislikes cats                19
# has dogs and has cats                     59
# has dogs and likes cats                   88
# likes cats                                61
# likes dogs                               380
# likes dogs and dislikes cats              72
# likes dogs and has cats                  245
# likes dogs and likes cats                691
# unknown                                  808
#
# religion                         agnosticism and laughing about it  \
# pets
# dislikes cats                                                    5
# ...

# %%
pd.crosstab(df['status'], df['gender'])
# Out:
# gender              f      m
# status
# available         656   1209
# married           135    175
# seeing someone   1003   1061
# single          22319  33378
# unknown             4      6

# %%
df['income'].groupby(df['status']).mean()
# Out:
# status
# available         27859.840751
# married           26063.793548
# seeing someone    23666.869671
# single            19605.809433
# unknown            3999.200000
# Name: income, dtype: float64

# %%
pd.crosstab(df['pets'], df['status'])
# Out:
# status                           available  married  seeing someone  single  \
# pets
# dislikes cats                            3        0               1     118
# dislikes dogs                            0        0               2      42
# dislikes dogs and dislikes cats          4        2               6     184
# dislikes dogs and has cats              11        4               5      61
# dislikes dogs and likes cats            23        3              22     192
# has cats                                87       14              63    1241
# has dogs                               100       23              89    3922
# has dogs and dislikes cats               7        5              13     527
# has dogs and has cats                   82       27              73    1291
# has dogs and likes cats                 96       17              92    2127
# likes cats                              53        5              84     921
# ...

# %%
df['income'].groupby(df['ethnicity']).mean()
# Out:
# ethnicity
# asian                                    14422.037822
# asian, black                             26270.406780
# asian, black, hispanic / latin              -1.000000
# asian, black, hispanic / latin, other       -1.000000
# asian, black, hispanic / latin, white       -1.000000
#                                              ...
# pacific islander, white                  15319.711538
# pacific islander, white, other           57776.944444
# unknown                                  18455.112676
# white                                    19526.170114
# white, other                             27315.932917
# Name: income, Length: 218, dtype: float64

# %%
pd.crosstab(df['ethnicity'], df['diet'])
# Out:
# diet                                   anything  halal  kosher  \
# ethnicity
# asian                                       749      2       0
# asian, black                                 11      0       0
# asian, black, hispanic / latin                0      0       0
# asian, black, hispanic / latin, other         0      0       0
# asian, black, hispanic / latin, white         0      0       0
# ...                                         ...    ...     ...
# pacific islander, white                      14      0       0
# pacific islander, white, other                2      0       0
# unknown                                     629      1       3
# white                                      3330      2       3
# white, other                                 48      0       0
#
# diet                                   mostly anything  mostly halal  \
# ethnicity
# asian                                             2086             2
# ...

# %%
print(df["income"].groupby(df["gender"]).mean())

###
plt.figure(figsize=(15,5))
plt.title('income Statistic by gender')

sns.barplot(data = df, x = "gender", y = "income", ci = None)
# Out:
# gender
# f    11181.697392
# m    25991.307656
# Name: income, dtype: float64
# <AxesSubplot:title={'center':'income Statistic by gender'}, xlabel='gender', ylabel='income'>

# %%
print(df["income"].groupby(df["ethnicity"]).mean())

###
plt.figure(figsize=(200,5))
plt.title('income Statistic by ethnicity')

sns.barplot(data = df, x = "ethnicity", y = "income", ci = None)
# Out:
# ethnicity
# asian                                    14422.037822
# asian, black                             26270.406780
# asian, black, hispanic / latin              -1.000000
# asian, black, hispanic / latin, other       -1.000000
# asian, black, hispanic / latin, white       -1.000000
#                                              ...
# pacific islander, white                  15319.711538
# pacific islander, white, other           57776.944444
# unknown                                  18455.112676
# white                                    19526.170114
# white, other                             27315.932917
# Name: income, Length: 218, dtype: float64
# <AxesSubplot:title={'center':'income Statistic by ethnicity'}, xlabel='ethnicity', ylabel='income'>

# %%
pd.crosstab(df['religion'], df['drugs'], margins = False, normalize = False)
# Out:
# drugs                                       never  often  sometimes  unknown
# religion
# agnosticism                                  1601      8        367      748
# agnosticism and laughing about it            1283     12        530      671
# agnosticism and somewhat serious about it     329      5        140      168
# agnosticism and very serious about it         152      5         76       81
# agnosticism but not too serious about it     1630     15        386      605
# atheism                                      1125     22        393      635
# atheism and laughing about it                 966     26        518      564
# atheism and somewhat serious about it         445      6        209      188
# atheism and very serious about it             279     19        161      111
# atheism but not too serious about it          704     14        256      344
# buddhism                                      250      0         40      113
# ...

# %%
df['nodrug_group'] = np.where(((df['age'] > 40) & (df['drinks'] == 'socially') & (df['drugs'] == 'never')), 1, 0)

# %%
df.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   36         average       mostly other     often  sometimes
# 2   37            thin           anything  socially    unknown
# 3   22            thin         vegetarian  socially    unknown
# 4   30        athletic            unknown  socially      never
#
#                            education            ethnicity height  income  \
# 0      working on college/university         asian, white   75.0      -1
# 1              working on space camp                white   70.0   80000
# 2     graduated from masters program              unknown   68.0      -1
# 3      working on college/university                white   71.0   20000
# 4  graduated from college/university  asian, black, other   66.0      -1
#
#                            job                                     offspring  \
# ...

# %%
df['nosmoke_group'] = np.where(((df['income'] > 50) & (df['smokes'] == 'never') & (df['orientation'] == 'straight')), 1, 0)

# %%
df.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   36         average       mostly other     often  sometimes
# 2   37            thin           anything  socially    unknown
# 3   22            thin         vegetarian  socially    unknown
# 4   30        athletic            unknown  socially      never
#
#                            education            ethnicity height  income  \
# 0      working on college/university         asian, white   75.0      -1
# 1              working on space camp                white   70.0   80000
# 2     graduated from masters program              unknown   68.0      -1
# 3      working on college/university                white   71.0   20000
# 4  graduated from college/university  asian, black, other   66.0      -1
#
#                            job  ... orientation                       pets  \
# ...

# %%
df['status_group'] = np.where(((df['gender'] > 'f') & (df['age'] > 35) & (df['status'] == 'single')), 1, 0)

# %%
df.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   36         average       mostly other     often  sometimes
# 2   37            thin           anything  socially    unknown
# 3   22            thin         vegetarian  socially    unknown
# 4   30        athletic            unknown  socially      never
#
#                            education            ethnicity height  income  \
# 0      working on college/university         asian, white   75.0      -1
# 1              working on space camp                white   70.0   80000
# 2     graduated from masters program              unknown   68.0      -1
# 3      working on college/university                white   71.0   20000
# 4  graduated from college/university  asian, black, other   66.0      -1
#
#                            job  ...                       pets  \
# 0               transportation  ...  likes dogs and likes cats
# ...

# %%
pd.crosstab(df['religion'], df['drugs'], margins = False, normalize = False)
# Out:
# drugs                                       never  often  sometimes  unknown
# religion
# agnosticism                                  1601      8        367      748
# agnosticism and laughing about it            1283     12        530      671
# agnosticism and somewhat serious about it     329      5        140      168
# agnosticism and very serious about it         152      5         76       81
# agnosticism but not too serious about it     1630     15        386      605
# atheism                                      1125     22        393      635
# atheism and laughing about it                 966     26        518      564
# atheism and somewhat serious about it         445      6        209      188
# atheism and very serious about it             279     19        161      111
# atheism but not too serious about it          704     14        256      344
# buddhism                                      250      0         40      113
# ...

# %%
pd.crosstab(df['religion'], df['pets'], margins = False, normalize = False)
# Out:
# pets                                        dislikes cats  dislikes dogs  \
# religion
# agnosticism                                             3              2
# agnosticism and laughing about it                       5              1
# agnosticism and somewhat serious about it               0              0
# agnosticism and very serious about it                   0              0
# agnosticism but not too serious about it                0              1
# atheism                                                 6              3
# atheism and laughing about it                           5              0
# atheism and somewhat serious about it                   2              3
# atheism and very serious about it                       3              1
# atheism but not too serious about it                    0              0
# buddhism                                                2              0
# buddhism and laughing about it                          2              0
# ...

# %%
df.groupby(df['drinks']).mean()
# Out:
#                    age        income  nodrug_group  nosmoke_group  \
# drinks
# desperately  29.639752  92452.695652      0.000000            0.0
# not at all   35.438323  21171.571472      0.000000            0.0
# often        30.530790  29369.864446      0.000000            0.0
# rarely       34.363942  18763.705221      0.000000            0.0
# socially     32.174055  18337.863834      0.118621            0.0
# unknown      31.137353  13235.256951      0.000000            0.0
# very often   28.690021  69787.050955      0.000000            0.0
#
#              status_group
# drinks
# desperately      0.124224
# not at all       0.237833
# often            0.119094
# rarely           0.191875
# socially         0.139397
# unknown          0.143049
# very often       0.095541

# %%
df.groupby(df['drugs']).mean()
# Out:
#                  age        income  nodrug_group  nosmoke_group  status_group
# drugs
# never      33.187732  17858.647360      0.131375            0.0      0.159103
# often      25.995122  94853.095122      0.000000            0.0      0.068293
# sometimes  29.871055  32477.294878      0.000000            0.0      0.104501
# unknown    31.589702  16847.140057      0.000000            0.0      0.144389

# %%
pd.crosstab(df['pets'], df['drugs'], margins = False, normalize = False)
# Out:
# drugs                            never  often  sometimes  unknown
# pets
# dislikes cats                       83      1         17       21
# dislikes dogs                       29      2          7        6
# dislikes dogs and dislikes cats    152      9         18       17
# dislikes dogs and has cats          48      5         15       13
# dislikes dogs and likes cats       137      5         68       30
# has cats                           836     17        236      317
# has dogs                          2802     24        418      890
# has dogs and dislikes cats         398      8         54       92
# has dogs and has cats              969     16        223      266
# has dogs and likes cats           1429     23        391      490
# likes cats                         604     11        186      262
# likes dogs                        4812     24        611     1777
# likes dogs and dislikes cats      1399     18        244      368
# ...

# %%
pd.crosstab(df['status'], df['drugs'], margins = False, normalize = False)
# Out:
# drugs           never  often  sometimes  unknown
# status
# available         779     20        558      508
# married           181      1         72       56
# seeing someone   1108     19        425      512
# single          35650    370       6677    13000
# unknown             6      0          0        4

# %%
pd.crosstab(df['pets'], df['status'], margins = False, normalize = False)
# Out:
# status                           available  married  seeing someone  single  \
# pets
# dislikes cats                            3        0               1     118
# dislikes dogs                            0        0               2      42
# dislikes dogs and dislikes cats          4        2               6     184
# dislikes dogs and has cats              11        4               5      61
# dislikes dogs and likes cats            23        3              22     192
# has cats                                87       14              63    1241
# has dogs                               100       23              89    3922
# has dogs and dislikes cats               7        5              13     527
# has dogs and has cats                   82       27              73    1291
# has dogs and likes cats                 96       17              92    2127
# likes cats                              53        5              84     921
# ...

# %%
pd.crosstab(df['job'], df['drinks'], margins = False, normalize = False)
# Out:
# drinks                             desperately  not at all  often  rarely  \
# job
# artistic / musical / writer                 43         287    458     502
# banking / financial / real estate            6          56    157     174
# clerical / administrative                    3          65     66      96
# computer / hardware / software              24         226    451     506
# construction / craftsmanship                 5          99     97     114
# education / academia                        12         184    255     399
# entertainment / media                        9          93    228     202
# executive / management                       6         100    189     193
# hospitality / travel                         9          61    230     101
# law / legal services                        12          48    112      96
# medicine / health                           15         233    176     472
# military                                     2          15     16      28
# ...

# %%
## simple barplot to show the average income across my group
# age > 40, drinks = socially, drugs = never
sns.barplot(data = df, x = "nodrug_group", y = "income", ci = None)

plt.title('income Statistic by nodrug_group')
plt.grid()

# %%
###  simple barplot to show the average age across mygroup1

# income > 50K, smokes = never, pets = likes dogs and cats

sns.barplot(data = df, x = "nosmoke_group", y = "age", ci = None)

plt.title('age Statistic by nosmoke_group')
plt.grid()

# %%
## barplot to show the average income across mygroup2

# age > 35, gender = f, status   = single

sns.barplot(data = df, x = "status_group", y = "income", ci = None)

plt.title('income Statistic by status_group')
plt.grid()

# %%
plt.figure(figsize=(15,5))
sns.countplot(df['smokes'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='smokes', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
sns.countplot(df['drugs'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='drugs', ylabel='count'>

# %%
#average income by age

plt.figure(figsize=(50,5))
sns.barplot(data = df, x = "age", y = "income", ci = None)

plt.title('income Statistic by age')
plt.grid()

# %%
#average age by drinks

plt.figure(figsize=(10,5))
sns.barplot(data = df, x = "drugs", y = "age", ci = None)

plt.title('age Statistic by drugs')
plt.grid()
## plt.minorticks_on()

# %%
plt.figure(figsize=(10,5))
sns.barplot(data = df, x = "drinks", y = "income", ci = None)

plt.title('income Statistic by drinks')
plt.grid()

# %%
plt.figure(figsize=(180,5))
sns.barplot(data = df, x = "religion", y = "income", ci = None)

plt.title('income Statistic by religion')
plt.grid()

# %%
dfz = df.copy()

# %%
dfz.head()
# Out:
#    age       body_type               diet drinks  drugs  \
# 0   22  a little extra  strictly anything      2    0.0
# 1   36         average       mostly other      3    2.0
# 2   37            thin           anything      2    NaN
# 3   22            thin         vegetarian      2    NaN
# 4   30        athletic                NaN      2    0.0
#
#                            education            ethnicity  height  income  \
# 0      working on college/university         asian, white    75.0      -1
# 1              working on space camp                white    70.0   80000
# 2     graduated from masters program                  NaN    68.0      -1
# 3      working on college/university                white    71.0   20000
# 4  graduated from college/university  asian, black, other    66.0      -1
#
#                            job                                     offspring  \
# 0               transportation  doesn&rsquo;t have kids, but might want them
# ...

# %%
df.isnull().sum()
# Out:
# age                0
# body_type       5296
# diet           24395
# drinks          2985
# drugs          14080
# education       6628
# ethnicity       5680
# height             3
# income             0
# job             8198
# offspring      35561
# orientation        0
# pets           19921
# religion       20226
# sex                0
# sign           11056
# smokes          5512
# speaks            50
# status             0
# dtype: int64

# %%
df.fillna('unknown', inplace = True)

# %%
df['drugs'].replace(['never', 'often', 'sometimes', 'unknown'], [0, 1, 2, 3], inplace = True)

# %%
df.head()
# Out:
#    age       body_type               diet drinks  drugs  \
# 0   22  a little extra  strictly anything      2    0.0
# 1   36         average       mostly other      3    2.0
# 2   37            thin           anything      2    3.0
# 3   22            thin         vegetarian      2    3.0
# 4   30        athletic            unknown      2    0.0
#
#                            education            ethnicity height  income  \
# 0      working on college/university         asian, white   75.0      -1
# 1              working on space camp                white   70.0   80000
# 2     graduated from masters program              unknown   68.0      -1
# 3      working on college/university                white   71.0   20000
# 4  graduated from college/university  asian, black, other   66.0      -1
#
#                            job                                     offspring  \
# 0               transportation  doesn&rsquo;t have kids, but might want them
# ...

# %%
plt.figure(figsize=(180,5))
sns.barplot(data = df, x = "religion", y = "drugs", ci = None)

plt.title('drugs Statistic by religion')
plt.grid()

# %%
df['drinks'].replace(['unknown', 'rarely', 'socially', 'often', 'very often', 'not at all', 'desperately'], [0, 1, 2, 3, 4, 5, 6, ], inplace = True)

# %%
df.head()
# Out:
#    age       body_type               diet  drinks  drugs  \
# 0   22  a little extra  strictly anything       2    0.0
# 1   36         average       mostly other       3    2.0
# 2   37            thin           anything       2    3.0
# 3   22            thin         vegetarian       2    3.0
# 4   30        athletic            unknown       2    0.0
#
#                            education            ethnicity height  income  \
# 0      working on college/university         asian, white   75.0      -1
# 1              working on space camp                white   70.0   80000
# 2     graduated from masters program              unknown   68.0      -1
# 3      working on college/university                white   71.0   20000
# 4  graduated from college/university  asian, black, other   66.0      -1
#
#                            job                                     offspring  \
# 0               transportation  doesn&rsquo;t have kids, but might want them
# ...

# %%
plt.figure(figsize=(180,5))

sns.barplot(data = df, x = "religion", y = "drinks", hue = "drugs", ci = None)

plt.xticks(rotation = -45)
plt.title( 'average drinks by drugs across religion')
plt.legend(loc = 'upper left')

# %%
plt.figure(figsize=(15,5))
sns.barplot(data = df, x = "drinks", y = "drugs", ci = None)

plt.title('drugs Statistic by drinks')
plt.grid()

# %%
plt.figure(figsize=(180,5))

sns.barplot(data = df, x = "pets", y = "drugs", hue = "drinks", ci = None)

plt.xticks(rotation = -45)
plt.title( 'average drugs  by drinks across pets')
plt.legend(loc = 'upper left')
